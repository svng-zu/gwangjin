# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd

# %%
csv = '/content/drive/MyDrive/공모전/데이터/학습용/데이터변환2.csv'

df = pd.read_csv(csv)

# %%
df
# Out:
#        Unnamed: 0  시간     속도   교통량        일자  요일  지점번호  방향    거리  차선수  기능유형구분  \
# 0               0   0  58.43   116  20220302   2  C-19   0  1228    3       0
# 1               1   1  57.97    92  20220302   2  C-19   0  1228    3       0
# 2               2   2  61.02   102  20220302   2  C-19   0  1228    3       0
# 3               3   3  61.25   174  20220302   2  C-19   0  1228    3       0
# 4               4   4  57.99   447  20220302   2  C-19   0  1228    3       0
# ...           ...  ..    ...   ...       ...  ..   ...  ..   ...  ...     ...
# 73867       73867  19  40.14  1601  20230131   1  C-20   1  1001    3       0
# 73868       73868  20  45.03  1434  20230131   1  C-20   1  1001    3       0
# 73869       73869  21  48.36  1211  20230131   1  C-20   1  1001    3       0
# 73870       73870  22  48.76   935  20230131   1  C-20   1  1001    3       0
# 73871       73871  23  52.41   593  20230131   1  C-20   1  1001    3       0
#
#        합류도로수  제한속도  주말 유무
# ...

# %%
df_1 = df[['속도', '교통량']]

# %%
df_1
# Out:
#           속도   교통량
# 0      58.43   116
# 1      57.97    92
# 2      61.02   102
# 3      61.25   174
# 4      57.99   447
# ...      ...   ...
# 73867  40.14  1601
# 73868  45.03  1434
# 73869  48.36  1211
# 73870  48.76   935
# 73871  52.41   593
#
# [73872 rows x 2 columns]

# %%
df_1['밀도'] = df_1['교통량']/df_1['속도']
# Out:
# <ipython-input-9-6fdefb652f5a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['밀도'] = df_1['교통량']/df_1['속도']

# %%
df_1
# Out:
#           속도   교통량         밀도
# 0      58.43   116   1.985282
# 1      57.97    92   1.587028
# 2      61.02   102   1.671583
# 3      61.25   174   2.840816
# 4      57.99   447   7.708226
# ...      ...   ...        ...
# 73867  40.14  1601  39.885401
# 73868  45.03  1434  31.845436
# 73869  48.36  1211  25.041356
# 73870  48.76   935  19.175554
# 73871  52.41   593  11.314635
#
# [73872 rows x 3 columns]

# %%
#이 데이터로 하면 상하행의 밀도차이가 큰 구간을 추출하기 어려움 -> 초기 데이터 활용

# %%
data = pd.read_excel('/content/drive/MyDrive/공모전/데이터/다시한거/합류도로, 제한속도, 밀도.xlsx')

# %%
data
# Out:
#             일자 요일    도로명  지점번호      시점명      종점명  방향    거리  차선수  기능유형구분  ...  \
# 0     20220302  수   강동대로  C-19  올림픽대교북단  올림픽대교남단  상행  1228    3   주간선도로  ...
# 1     20220302  수   강동대로  C-19  올림픽대교남단  올림픽대교북단  하행  1228    3   주간선도로  ...
# 2     20220302  수    동일로  D-07    화양사거리    군자교동단  상행  1350    3   주간선도로  ...
# 3     20220302  수    동일로  D-07    군자교동단    화양사거리  하행  1350    2   주간선도로  ...
# 4     20220302  수  분당수서로  C-17   청담대교북단   청담대교남단  상행  1575    3  도시고속도로  ...
# ...        ... ..    ...   ...      ...      ...  ..   ...  ...     ...  ...
# 3073  20230131  화  분당수서로  C-17   청담대교남단   청담대교북단  하행  1138    3  도시고속도로  ...
# 3074  20230131  화   송파대로  C-18   잠실대교북단   잠실대교남단  상행  1171    4   주간선도로  ...
# 3075  20230131  화   송파대로  C-18   잠실대교남단   잠실대교북단  하행  1175    4   주간선도로  ...
# 3076  20230131  화   천호대로  C-20   천호대교북단   천호대교남단  상행  1001    3   주간선도로  ...
# 3077  20230131  화   천호대로  C-20   천호대교남단   천호대교북단  하행  1001    3   주간선도로  ...
#
# ...

# %%
data.columns
# Out:
# Index(['일자', '요일', '도로명', '지점번호', '시점명', '종점명', '방향', '거리', '차선수', '기능유형구분',
#        '도심/외곽구분', '권역구분', '01시_속도', '02시_속도', '03시_속도', '04시_속도', '05시_속도',
#        '06시_속도', '07시_속도', '08시_속도', '09시_속도', '10시_속도', '11시_속도', '12시_속도',
#        '13시_속도', '14시_속도', '15시_속도', '16시_속도', '17시_속도', '18시_속도', '19시_속도',
#        '20시_속도', '21시_속도', '22시_속도', '23시_속도', '24시_속도', '01시_교통량', '02시_교통량',
#        '03시_교통량', '04시_교통량', '05시_교통량', '06시_교통량', '07시_교통량', '08시_교통량',
#        '09시_교통량', '10시_교통량', '11시_교통량', '12시_교통량', '13시_교통량', '14시_교통량',
#        '15시_교통량', '16시_교통량', '17시_교통량', '18시_교통량', '19시_교통량', '20시_교통량',
#        '21시_교통량', '22시_교통량', '23시_교통량', '24시_교통량', '합류도로수', '제한속도', '01시_밀도',
#        '02시_밀도', '03시_밀도', '04시_밀도', '05시_밀도', '06시_밀도', '07시_밀도', '08시_밀도',
#        '09시_밀도', '10시_밀도', '11시_밀도', '12시_밀도', '13시_밀도', '14시_밀도', '15시_밀도',
#        '16시_밀도', '17시_밀도', '18시_밀도', '19시_밀도', '20시_밀도', '21시_밀도', '22시_밀도',
#        '23시_밀도', '24시_밀도'],
#       dtype='object')

# %%
df_2 = data[['지점번호', '시점명', '종점명']]
df_2 = df_2.drop_duplicates()

# %%
df_2
# Out:
#    지점번호      시점명      종점명
# 0  C-19  올림픽대교북단  올림픽대교남단
# 1  C-19  올림픽대교남단  올림픽대교북단
# 2  D-07    화양사거리    군자교동단
# 3  D-07    군자교동단    화양사거리
# 4  C-17   청담대교북단   청담대교남단
# 5  C-17   청담대교남단   청담대교북단
# 6  C-18   잠실대교북단   잠실대교남단
# 7  C-18   잠실대교남단   잠실대교북단
# 8  C-20   천호대교북단   천호대교남단
# 9  C-20   천호대교남단   천호대교북단

# %%
#광진구에서 후보로 둘 수 있는 구간의 수는 5개 (C-19, D-07, C-17, C-18, C-20)
# 각 지점별 밀도의 평균을 구하기 위해서 시간대별 속도와 교통량의 평균을 구한 후 밀도 의 평균을 구해서 밀도의 차이가 가장큰 구간 찾기
# 5개 구간은 올림픽대교, 화양사거리-> 군자교, 청담대교, 잠실대교, 천호대교로 구성

# %%
road_1 = data[data['방향']=='상행']
road_2 = data[data['방향']=='하행']

# %%
road_1
# Out:
#             일자 요일    도로명  지점번호      시점명      종점명  방향    거리  차선수  기능유형구분  ...  \
# 0     20220302  수   강동대로  C-19  올림픽대교북단  올림픽대교남단  상행  1228    3   주간선도로  ...
# 2     20220302  수    동일로  D-07    화양사거리    군자교동단  상행  1350    3   주간선도로  ...
# 4     20220302  수  분당수서로  C-17   청담대교북단   청담대교남단  상행  1575    3  도시고속도로  ...
# 6     20220302  수   송파대로  C-18   잠실대교북단   잠실대교남단  상행  1171    4   주간선도로  ...
# 8     20220302  수   천호대로  C-20   천호대교북단   천호대교남단  상행  1001    3   주간선도로  ...
# ...        ... ..    ...   ...      ...      ...  ..   ...  ...     ...  ...
# 3068  20230131  화   강동대로  C-19  올림픽대교북단  올림픽대교남단  상행  1228    3   주간선도로  ...
# 3070  20230131  화    동일로  D-07    화양사거리    군자교동단  상행  1350    3   주간선도로  ...
# 3072  20230131  화  분당수서로  C-17   청담대교북단   청담대교남단  상행  1575    3  도시고속도로  ...
# 3074  20230131  화   송파대로  C-18   잠실대교북단   잠실대교남단  상행  1171    4   주간선도로  ...
# 3076  20230131  화   천호대로  C-20   천호대교북단   천호대교남단  상행  1001    3   주간선도로  ...
#
# ...

# %%
road_2
# Out:
#             일자 요일    도로명  지점번호      시점명      종점명  방향    거리  차선수  기능유형구분  ...  \
# 1     20220302  수   강동대로  C-19  올림픽대교남단  올림픽대교북단  하행  1228    3   주간선도로  ...
# 3     20220302  수    동일로  D-07    군자교동단    화양사거리  하행  1350    2   주간선도로  ...
# 5     20220302  수  분당수서로  C-17   청담대교남단   청담대교북단  하행  1138    3  도시고속도로  ...
# 7     20220302  수   송파대로  C-18   잠실대교남단   잠실대교북단  하행  1175    4   주간선도로  ...
# 9     20220302  수   천호대로  C-20   천호대교남단   천호대교북단  하행  1001    3   주간선도로  ...
# ...        ... ..    ...   ...      ...      ...  ..   ...  ...     ...  ...
# 3069  20230131  화   강동대로  C-19  올림픽대교남단  올림픽대교북단  하행  1228    3   주간선도로  ...
# 3071  20230131  화    동일로  D-07    군자교동단    화양사거리  하행  1350    2   주간선도로  ...
# 3073  20230131  화  분당수서로  C-17   청담대교남단   청담대교북단  하행  1138    3  도시고속도로  ...
# 3075  20230131  화   송파대로  C-18   잠실대교남단   잠실대교북단  하행  1175    4   주간선도로  ...
# 3077  20230131  화   천호대로  C-20   천호대교남단   천호대교북단  하행  1001    3   주간선도로  ...
#
# ...

# %%
c_17_0 = road_1[road_1['지점번호']=='C-17']
c_17_1 = road_2[road_2['지점번호']=='C-17']

# %%
'일자', '요일', '도로명', '지점번호', '시점명', '종점명', '방향', '거리', '차선수', '기능유형구분',
       '도심/외곽구분', '권역구분', '01시_속도', '02시_속도', '03시_속도', '04시_속도', '05시_속도',
       '06시_속도', '07시_속도', '08시_속도', '09시_속도', '10시_속도', '11시_속도', '12시_속도',
       '13시_속도', '14시_속도', '15시_속도', '16시_속도', '17시_속도', '18시_속도', '19시_속도',
       '20시_속도', '21시_속도', '22시_속도', '23시_속도', '24시_속도', '01시_교통량', '02시_교통량',
       '03시_교통량', '04시_교통량', '05시_교통량', '06시_교통량', '07시_교통량', '08시_교통량',
       '09시_교통량', '10시_교통량', '11시_교통량', '12시_교통량', '13시_교통량', '14시_교통량',
       '15시_교통량', '16시_교통량', '17시_교통량', '18시_교통량', '19시_교통량', '20시_교통량',
       '21시_교통량', '22시_교통량', '23시_교통량', '24시_교통량', '합류도로수', '제한속도', '01시_밀도',
       '02시_밀도', '03시_밀도', '04시_밀도', '05시_밀도', '06시_밀도', '07시_밀도', '08시_밀도',
       '09시_밀도', '10시_밀도', '11시_밀도', '12시_밀도', '13시_밀도', '14시_밀도', '15시_밀도',
       '16시_밀도', '17시_밀도', '18시_밀도', '19시_밀도', '20시_밀도', '21시_밀도', '22시_밀도',
       '23시_밀도', '24시_밀도']

# %%
c_17_0 = c_17_0[['01시_밀도',
       '02시_밀도', '03시_밀도', '04시_밀도', '05시_밀도', '06시_밀도', '07시_밀도', '08시_밀도',
       '09시_밀도', '10시_밀도', '11시_밀도', '12시_밀도', '13시_밀도', '14시_밀도', '15시_밀도',
       '16시_밀도', '17시_밀도', '18시_밀도', '19시_밀도', '20시_밀도', '21시_밀도', '22시_밀도',
       '23시_밀도', '24시_밀도']]

# %%
c_17_1 = c_17_1[['01시_밀도',
       '02시_밀도', '03시_밀도', '04시_밀도', '05시_밀도', '06시_밀도', '07시_밀도', '08시_밀도',
       '09시_밀도', '10시_밀도', '11시_밀도', '12시_밀도', '13시_밀도', '14시_밀도', '15시_밀도',
       '16시_밀도', '17시_밀도', '18시_밀도', '19시_밀도', '20시_밀도', '21시_밀도', '22시_밀도',
       '23시_밀도', '24시_밀도']]

# %%
c_17_0 = c_17_0.mean()
c_17_1 = c_17_1.mean()

# %%
c_17_0.max()-c_17_1.max()
# Out:
# 96.6959309266532

# %%
c_18_0 = road_1[road_1['지점번호']=='C-18']
c_18_1 = road_2[road_2['지점번호']=='C-18']
c_19_0 = road_1[road_1['지점번호']=='C-19']
c_19_1 = road_2[road_2['지점번호']=='C-19']
c_20_0 = road_1[road_1['지점번호']=='C-20']
c_20_1 = road_2[road_2['지점번호']=='C-20']
d_07_0 = road_1[road_1['지점번호']=='D-07']
d_07_1 = road_2[road_2['지점번호']=='D-07']

# %%
c_18_0 = c_18_0[['01시_밀도',
       '02시_밀도', '03시_밀도', '04시_밀도', '05시_밀도', '06시_밀도', '07시_밀도', '08시_밀도',
       '09시_밀도', '10시_밀도', '11시_밀도', '12시_밀도', '13시_밀도', '14시_밀도', '15시_밀도',
       '16시_밀도', '17시_밀도', '18시_밀도', '19시_밀도', '20시_밀도', '21시_밀도', '22시_밀도',
       '23시_밀도', '24시_밀도']]
c_18_1 = c_18_1[['01시_밀도',
       '02시_밀도', '03시_밀도', '04시_밀도', '05시_밀도', '06시_밀도', '07시_밀도', '08시_밀도',
       '09시_밀도', '10시_밀도', '11시_밀도', '12시_밀도', '13시_밀도', '14시_밀도', '15시_밀도',
       '16시_밀도', '17시_밀도', '18시_밀도', '19시_밀도', '20시_밀도', '21시_밀도', '22시_밀도',
       '23시_밀도', '24시_밀도']]
c_19_0 = c_19_0[['01시_밀도',
       '02시_밀도', '03시_밀도', '04시_밀도', '05시_밀도', '06시_밀도', '07시_밀도', '08시_밀도',
       '09시_밀도', '10시_밀도', '11시_밀도', '12시_밀도', '13시_밀도', '14시_밀도', '15시_밀도',
       '16시_밀도', '17시_밀도', '18시_밀도', '19시_밀도', '20시_밀도', '21시_밀도', '22시_밀도',
       '23시_밀도', '24시_밀도']]
c_19_1 = c_19_1[['01시_밀도',
       '02시_밀도', '03시_밀도', '04시_밀도', '05시_밀도', '06시_밀도', '07시_밀도', '08시_밀도',
       '09시_밀도', '10시_밀도', '11시_밀도', '12시_밀도', '13시_밀도', '14시_밀도', '15시_밀도',
       '16시_밀도', '17시_밀도', '18시_밀도', '19시_밀도', '20시_밀도', '21시_밀도', '22시_밀도',
       '23시_밀도', '24시_밀도']]
c_20_0 = c_20_0[['01시_밀도',
       '02시_밀도', '03시_밀도', '04시_밀도', '05시_밀도', '06시_밀도', '07시_밀도', '08시_밀도',
       '09시_밀도', '10시_밀도', '11시_밀도', '12시_밀도', '13시_밀도', '14시_밀도', '15시_밀도',
       '16시_밀도', '17시_밀도', '18시_밀도', '19시_밀도', '20시_밀도', '21시_밀도', '22시_밀도',
       '23시_밀도', '24시_밀도']]
c_20_1 = c_20_1[['01시_밀도',
       '02시_밀도', '03시_밀도', '04시_밀도', '05시_밀도', '06시_밀도', '07시_밀도', '08시_밀도',
       '09시_밀도', '10시_밀도', '11시_밀도', '12시_밀도', '13시_밀도', '14시_밀도', '15시_밀도',
       '16시_밀도', '17시_밀도', '18시_밀도', '19시_밀도', '20시_밀도', '21시_밀도', '22시_밀도',
       '23시_밀도', '24시_밀도']]
d_07_0 = d_07_0[['01시_밀도',
       '02시_밀도', '03시_밀도', '04시_밀도', '05시_밀도', '06시_밀도', '07시_밀도', '08시_밀도',
       '09시_밀도', '10시_밀도', '11시_밀도', '12시_밀도', '13시_밀도', '14시_밀도', '15시_밀도',
       '16시_밀도', '17시_밀도', '18시_밀도', '19시_밀도', '20시_밀도', '21시_밀도', '22시_밀도',
       '23시_밀도', '24시_밀도']]
d_07_1 = d_07_1[['01시_밀도',
       '02시_밀도', '03시_밀도', '04시_밀도', '05시_밀도', '06시_밀도', '07시_밀도', '08시_밀도',
       '09시_밀도', '10시_밀도', '11시_밀도', '12시_밀도', '13시_밀도', '14시_밀도', '15시_밀도',
       '16시_밀도', '17시_밀도', '18시_밀도', '19시_밀도', '20시_밀도', '21시_밀도', '22시_밀도',
       '23시_밀도', '24시_밀도']]

# %%
c_18_0 = c_18_0.mean()
c_18_1 = c_18_1.mean()
c_19_0 = c_19_0.mean()
c_19_1 = c_19_1.mean()
c_20_0 = c_20_0.mean()
c_20_1 = c_20_1.mean()
d_07_0 = d_07_0.mean()
d_07_1 = d_07_1.mean()

# %%
c_18_0.max() - c_18_1.max()
# Out:
# 5.295106283486021

# %%
c_19_0.max() - c_19_1.max()
# Out:
# 6.933024787016862

# %%
c_20_0.max() - c_20_1.max()
# Out:
# -13.691355814090734

# %%
d_07_0.max() - d_07_1.max()
# Out:
# -105.88504303997448

# %%
#각 평균값의 상, 하행의 최대값의 차이만 보았을 때는 d-07, c-17, c-20, c-19, c-18 순이다.

# %%
c_17_0.max()/c_17_1.max()
# Out:
# 2.045600039952479

# %%
c_18_0.max()/ c_18_1.max()
# Out:
# 1.0934696081377226

# %%
c_19_0.max() / c_19_1.max()
# Out:
# 1.154519062494262

# %%
c_20_0.max() / c_20_1.max()
# Out:
# 0.7973537030302258

# %%
d_07_0.max() /d_07_1.max()
# Out:
# 0.3237136660336106

# %%
#각 평균값의 상, 하행의 최대값의 비율만 보았을 때는 d-07, c-17, c-20, c-19, c-18 순이다. 밀도 차와 동일.

# %%
c_17 = max(abs(c_17_0 -c_17_1))
c_18 = max(abs(c_18_0 -c_18_1))
c_19 = max(abs(c_19_0 -c_19_1))
c_20 = max(abs(c_20_0 -c_20_1))
d_07 = max(abs(d_07_0 -d_07_1))

# %%
print(c_17, c_18, c_19, c_20, d_07)
# Out:
# 130.64006110782864 16.981060443607365 9.802660986375265 17.1198953932724 105.88504303997448

# %%
#시간별 밀도의 차가 가장 큰 구간은 c-17, d-07, c-20, c-18, c-19 순이다.

# %%
c1_17 = max(abs(c_17_0 /c_17_1))
c1_18 = max(abs(c_18_0 /c_18_1))
c1_19 = max(abs(c_19_0 /c_19_1))
c1_20 = max(abs(c_20_0 /c_20_1))
d1_07 = max(abs(d_07_0 /d_07_1))

# %%
print(c1_17, c1_18, c1_19, c1_20, d1_07)
# Out:
# 3.2569024553351222 1.1075271490136545 1.279154905771715 0.8946627107193476 1.8745160364006095

# %%
#시간별 밀도의 비가 가장 큰 구간은 c-17, d-07, c-19, c-18, c-20 순이다.

# %%
#단순 도로의 밀도차이는 d-07이 가장 컸으며, 시간당 밀도의 차이값이 가장 큰것은 c-17이였다. 
# 따라서 두 도로에 대해 설치 효율이 더 높은 도로로 최종 선정하도록 하겠다. (군자교c-17, 청담대교d-07)

# %%
#d-07은 일반도로로써 로드지퍼의 설치가 유용하지 않다. 그 이유는 신호등의 유무가 있는데, 신호등에 의해 교통량과 속도가 통제받는 상황에서는 자유도로에 적합한 로드지퍼는 적절하지않다.
#따라서 c-17만이 가장 뚜렷한 동일 시간대 밀도차이가 존재함을 보이기 때문에, c-17로 선정하고 그 효율성에 따라 최종 로드지퍼 설치 유무를 결정하겠다.
