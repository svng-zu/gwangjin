# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

csv = '/content/drive/MyDrive/공모전/데이터/다시한거/합류도로, 제한속도, 밀도.xlsx'
csvv = pd.read_excel(csv)

# %%
csvv
# Out:
#             일자 요일    도로명  지점번호      시점명      종점명  방향    거리  차선수  기능유형구분  ...  \
# 0     20220302  수   강동대로  C-19  올림픽대교북단  올림픽대교남단  상행  1228    3   주간선도로  ...
# 1     20220302  수   강동대로  C-19  올림픽대교남단  올림픽대교북단  하행  1228    3   주간선도로  ...
# 2     20220302  수    동일로  D-07    화양사거리    군자교동단  상행  1350    3   주간선도로  ...
# 3     20220302  수    동일로  D-07    군자교동단    화양사거리  하행  1350    2   주간선도로  ...
# 4     20220302  수  분당수서로  C-17   청담대교북단   청담대교남단  상행  1575    3  도시고속도로  ...
# ...        ... ..    ...   ...      ...      ...  ..   ...  ...     ...  ...
# 3073  20230131  화  분당수서로  C-17   청담대교남단   청담대교북단  하행  1138    3  도시고속도로  ...
# 3074  20230131  화   송파대로  C-18   잠실대교북단   잠실대교남단  상행  1171    4   주간선도로  ...
# 3075  20230131  화   송파대로  C-18   잠실대교남단   잠실대교북단  하행  1175    4   주간선도로  ...
# 3076  20230131  화   천호대로  C-20   천호대교북단   천호대교남단  상행  1001    3   주간선도로  ...
# 3077  20230131  화   천호대로  C-20   천호대교남단   천호대교북단  하행  1001    3   주간선도로  ...
#
# ...

# %%
csvv.columns
# Out:
# Index(['일자', '요일', '도로명', '지점번호', '시점명', '종점명', '방향', '거리', '차선수', '기능유형구분',
#        '도심/외곽구분', '권역구분', '01시_속도', '02시_속도', '03시_속도', '04시_속도', '05시_속도',
#        '06시_속도', '07시_속도', '08시_속도', '09시_속도', '10시_속도', '11시_속도', '12시_속도',
#        '13시_속도', '14시_속도', '15시_속도', '16시_속도', '17시_속도', '18시_속도', '19시_속도',
#        '20시_속도', '21시_속도', '22시_속도', '23시_속도', '24시_속도', '01시_교통량', '02시_교통량',
#        '03시_교통량', '04시_교통량', '05시_교통량', '06시_교통량', '07시_교통량', '08시_교통량',
#        '09시_교통량', '10시_교통량', '11시_교통량', '12시_교통량', '13시_교통량', '14시_교통량',
#        '15시_교통량', '16시_교통량', '17시_교통량', '18시_교통량', '19시_교통량', '20시_교통량',
#        '21시_교통량', '22시_교통량', '23시_교통량', '24시_교통량', '합류도로수', '제한속도', '01시_밀도',
#        '02시_밀도', '03시_밀도', '04시_밀도', '05시_밀도', '06시_밀도', '07시_밀도', '08시_밀도',
#        '09시_밀도', '10시_밀도', '11시_밀도', '12시_밀도', '13시_밀도', '14시_밀도', '15시_밀도',
#        '16시_밀도', '17시_밀도', '18시_밀도', '19시_밀도', '20시_밀도', '21시_밀도', '22시_밀도',
#        '23시_밀도', '24시_밀도'],
#       dtype='object')

# %%
df = csvv[['지점번호', '방향','합류도로수','제한속도']]

# %%
df
# Out:
#       지점번호  방향  합류도로수  제한속도
# 0     C-19  상행      2    60
# 1     C-19  하행      2    60
# 2     D-07  상행      0    50
# 3     D-07  하행      0    50
# 4     C-17  상행      3    80
# ...    ...  ..    ...   ...
# 3073  C-17  하행      2    80
# 3074  C-18  상행      2    60
# 3075  C-18  하행      2    60
# 3076  C-20  상행      2    60
# 3077  C-20  하행      2    60
#
# [3078 rows x 4 columns]

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#    지점번호  방향  합류도로수  제한속도
# 0  C-19  상행      2    60
# 1  C-19  하행      2    60
# 2  D-07  상행      0    50
# 3  D-07  하행      0    50
# 4  C-17  상행      3    80
# 5  C-17  하행      2    80
# 6  C-18  상행      2    60
# 7  C-18  하행      2    60
# 8  C-20  상행      2    60
# 9  C-20  하행      2    60

# %%
ori_df = pd.read_csv('/content/drive/MyDrive/공모전/데이터/학습용/데이터변환1.csv')

# %%
ori_df['합류도로수'] = 0
ori_df['제한속도'] = 0

# %%
ori_df
# Out:
#        Unnamed: 0  시간     속도   교통량        일자  요일   도로명  지점번호      시점명  \
# 0               0   0  58.43   116  20220302   2  강동대로  C-19  올림픽대교북단
# 1               1   1  57.97    92  20220302   2  강동대로  C-19  올림픽대교북단
# 2               2   2  61.02   102  20220302   2  강동대로  C-19  올림픽대교북단
# 3               3   3  61.25   174  20220302   2  강동대로  C-19  올림픽대교북단
# 4               4   4  57.99   447  20220302   2  강동대로  C-19  올림픽대교북단
# ...           ...  ..    ...   ...       ...  ..   ...   ...      ...
# 37435       37435  19  42.84  1125  20230131   1  천호대로  C-20   천호대교북단
# 37436       37436  20  44.97   998  20230131   1  천호대로  C-20   천호대교북단
# 37437       37437  21  47.14   954  20230131   1  천호대로  C-20   천호대교북단
# 37438       37438  22  49.55   701  20230131   1  천호대로  C-20   천호대교북단
# 37439       37439  23  51.73   496  20230131   1  천호대로  C-20   천호대교북단
#
#            종점명  방향    거리  차선수 기능유형구분 도심/외곽구분 권역구분  합류도로수  제한속도
# 0      올림픽대교남단  상행  1228    3  주간선도로      외곽  광진구      0     0
# ...

# %%
for i in range(0, 37440) :
  if ori_df['지점번호'][i] == 'C-19' :
    if ori_df['방향'] == '상행' :
      ori_df['합류도로수'][i] == 2, ori_df['제한속도'][i] == 60
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-f2e4d7406fbb> in <cell line: 1>()
#       1 for i in range(0, 37440) :
#       2   if ori_df['지점번호'][i] == 'C-19' :
# ----> 3     if ori_df['방향'] == '상행' :
#       4       ori_df['합류도로수'][i] == 2, ori_df['제한속도'][i] == 60
#       5
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1525     @final
#    1526     def __nonzero__(self) -> NoReturn:
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
