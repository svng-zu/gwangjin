# %%
# !pip install geopandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
import geopandas as gpd
import matplotlib.pyplot as plt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 57.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 95.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
plt.rcParams["font.family"] = 'NanumGothic'
plt.rcParams["figure.figsize"] = (10, 10)

seoul = gpd.read_file('sig.shp', encoding = 'euc-kr')
seoul
# Out:
#     SIG_CD    SIG_ENG_NM SIG_KOR_NM  \
# 0    11110     Jongno-gu        종로구
# 1    11140       Jung-gu         중구
# 2    11170    Yongsan-gu        용산구
# 3    11200  Seongdong-gu        성동구
# 4    11215   Gwangjin-gu        광진구
# ..     ...           ...        ...
# 245  48870   Hamyang-gun        함양군
# 246  48880  Geochang-gun        거창군
# 247  48890  Hapcheon-gun        합천군
# 248  50110       Jeju-si        제주시
# 249  50130   Seogwipo-si       서귀포시
#
#                                               geometry
# 0    POLYGON ((956615.453 1953567.199, 956621.579 1...
# 1    POLYGON ((957890.386 1952616.746, 957909.908 1...
# 2    POLYGON ((953115.761 1950834.084, 953114.206 1...
# 3    POLYGON ((959681.109 1952649.605, 959842.412 1...
# 4    POLYGON ((964825.058 1952633.250, 964875.565 1...
# ..                                                 ...
# 245  POLYGON ((1017715.723 1751280.191, 1017761.619...
# 246  POLYGON ((1034571.593 1767759.812, 1034559.208...
# ...

# %%
df = gpd.read_file('MOCT_LINK.shp', encoding = 'euc-kr')
df
# Out:
#            LINK_ID      F_NODE      T_NODE  LANES ROAD_RANK ROAD_TYPE ROAD_NO  \
# 0       3521214301  3520490601  3520490701      1       107       000       -
# 1       3521214201  3520490701  3520490501      1       107       000       -
# 2       1540081300  1540027000  1540028000      3       104       004       -
# 3       1540081400  1540028000  1540027000      3       104       004       -
# 4       1540084700  1540028000  1540028300      3       104       000       -
# ...            ...         ...         ...    ...       ...       ...     ...
# 538614  3970321601  3970090801  3970090701      1       103       003       3
# 538615  3970321701  3970090701  3970090801      1       103       003       3
# 538616  3970321201  3970090701  3970090601      1       103       000       3
# 538617  3970321301  3970090601  3970090701      1       103       000       3
# 538618  3970321401  3970012600  3970090601      1       103       000       3
#
# ...

# %%
df2 = gpd.read_file('MOCT_NODE.shp', encoding = 'euc-kr')
df2
# Out:
# WARNING:fiona._env:One or several characters couldn't be converted correctly from EUC-KR to UTF-8.  This warning will not be emitted anymore
#            NODE_ID NODE_TYPE NODE_NAME TURN_P  REMARK  \
# 0       3520490701       101         -      0     NaN
# 1       3300002000       101     태평삼거리      0     NaN
# 2       3300003000       101     태안삼거리      0     NaN
# 3       3300004300       101     압록사거리      1     NaN
# 4       2180135401       101      송희농원      0     NaN
# ...            ...       ...       ...    ...     ...
# 200211  2450048401       101         -      0  교차로명없음
# 200212  2310325101       101         -      0  교차로명없음
# 200213  2310325001       101         -      0  교차로명없음
# 200214  2290226101       104      산단TG      0     NaN
# 200215  2290226001       104      산단TG      0     NaN
#
#                              geometry
# 0       POINT (399316.904 365407.646)
# 1       POINT (229039.507 283709.367)
# 2       POINT (231445.784 285032.095)
# ...

# %%
mapping = pd.read_excel('서울특별시 표준링크 매핑정보.xlsx')
mapping = mapping.drop("표준링크순서", axis = 1)
mapping = mapping.drop_duplicates(subset=['서비스링크'])

mapping

speed = pd.merge(left=speed, right=mapping, how = 'inner', lefh_on = '링크아이디', right_on = '서비스링크')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-2fab76374ae9> in <cell line: 7>()
#       5 mapping
#       6
# ----> 7 speed = pd.merge(left=speed, right=mapping, how = 'inner', lefh_on = '링크아이디', right_on = '서비스링크')
#
# NameError: name 'speed' is not defined
